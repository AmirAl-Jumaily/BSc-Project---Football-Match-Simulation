# %%
import pandas as pd

import utils as u

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 500)

cfg = u.get_config()
data_cfg = u.get_config("data")

# %%
feature_data = pd.read_csv("data/csv_of_json_data/feature/match_stats.csv")
clean_data = pd.read_csv("data/csv_of_json_data/clean/match_stats.csv")
events_data = pd.read_csv("data/csv_of_json_data/clean/match_events.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (14,15,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
display(feature_data.head(3))
display(clean_data.head(3))
display(events_data.head(3))
# Out:
#    fixture_id  country     league_name  league_id league_type  league_season  \
# 0          65  England  Premier League          2      League           2018
# 1          66  England  Premier League          2      League           2018
# 2          67  England  Premier League          2      League           2018
#
#   fixture_date       fixture_round  fixture_status  fixture_elapsed  \
# 0   10/08/2018  Regular Season - 1  Match Finished               90
# 1   11/08/2018  Regular Season - 1  Match Finished               90
# 2   11/08/2018  Regular Season - 1  Match Finished               90
#
#                          fixture_venue           fixture_referee  \
# 0             Old Trafford, Manchester   Andre Marriner, England
# 1  St James' Park, Newcastle upon Tyne  Martin Atkinson, England
# 2        Vitality Stadium, Bournemouth     Kevin Friend, England
#
#   fixture_result_ht fixture_result_ft fixture_result_et fixture_result_pen  \
# ...
