# %% [markdown]
# # Contents:
#    ### 0) [Setup](#setup)
#    ### 1) [Basic view of data with some filtering](#first)
#    ### 2) [Seperating fixtures into those with all match stats and those with at least some](#second)
#    ### 3) [Proportions of games that have all match statistics](#third)
#    ### 4) [Investigating rows that have at least 1 match stat missing](#fourth)
#    ### 5) [Seperating League and Cup games](#fifth)

# %% [markdown]
# ---
# <a id='setup'></a>

# %% [markdown]
# ## 0) Setup

# %%
import pandas as pd

import convert_json_to_csv as jtocsv
import utils as u

cfg = u.get_config()
data_cfg = u.get_config("data")

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 200)

# %%
fixture_filepaths = u.get_all_files_with_name("fixtures_all.json", file_dirs=cfg['ALL_LEAGUES_AND_CUPS'])

match_stats = jtocsv.create_match_statistics_df_from_json(
    fixture_filepaths,
    file_to_save_match_stats="match_stats.csv",
    file_to_save_extra_data="extra_data.json",
    return_match_stats_df=True,
    verbose=False, read_data_if_exists=True)

# %% [markdown]
# ---
# <a id='first'></a>

# %% [markdown]
# ## 1) Basic view of data with some filtering

# %%
print(match_stats.shape)
match_stats.head()
# Out:
# (23677, 55)
#   fixture_id  country league_name league_id league_type league_season  \
# 0     276393  England      FA Cup      1063         Cup          2019
# 1     276394  England      FA Cup      1063         Cup          2019
# 2     276395  England      FA Cup      1063         Cup          2019
# 3     276396  England      FA Cup      1063         Cup          2019
# 4     276397  England      FA Cup      1063         Cup          2019
#
#   fixture_date            fixture_round  fixture_status fixture_elapsed  \
# 0   09/08/2019  Extra Preliminary Round  Match Finished              90
# 1   09/08/2019  Extra Preliminary Round  Match Finished              90
# 2   09/08/2019  Extra Preliminary Round  Match Finished              90
# 3   09/08/2019  Extra Preliminary Round  Match Finished              90
# 4   09/08/2019  Extra Preliminary Round  Match Finished              90
#
#                                  fixture_venue fixture_referee  \
# 0           Valerie Park (Prescot, Merseyside)             NaN
# 1             The Harlow Arena (Harlow, Essex)             NaN
# 2            Wibbandune Sports Ground (London)             NaN
# 3  The Polegrove (Bexhill-on-Sea, East Sussex)             NaN
# 4          Leg O'Mutton Field (Cobham, Surrey)             NaN
#
#   fixture_result_ht fixture_result_ft fixture_result_et fixture_result_pen  \
# 0               NaN               1-1               NaN                NaN
# 1               NaN               1-1               NaN                NaN
# 2               NaN               1-0               NaN                NaN
# 3               NaN               1-6               NaN                NaN
# 4               NaN               1-1               NaN                NaN
#
#          home_team_name home_team_id    away_team_name away_team_id  \
# 0   Skelmersdale United         8937  Penistone Church         8895
# 1         Woodford Town         9009      White Ensign         8998
# 2                Balham         8695          Rusthall         8917
# 3        Bexhill United         8704   Eastbourne Town         8769
# 4  Sutton Common Rovers         8962           Molesey         8874
#
#    home_goals  away_goals  has_match_stats  home_shots_ont  away_shots_ont  \
# 0         1.0         1.0            False             NaN             NaN
# 1         1.0         1.0            False             NaN             NaN
# 2         1.0         0.0            False             NaN             NaN
# 3         1.0         6.0            False             NaN             NaN
# 4         1.0         1.0            False             NaN             NaN
#
#    home_shots_offt  away_shots_offt  home_shots_tot  away_shots_tot  \
# 0              NaN              NaN             NaN             NaN
# 1              NaN              NaN             NaN             NaN
# 2              NaN              NaN             NaN             NaN
# 3              NaN              NaN             NaN             NaN
# 4              NaN              NaN             NaN             NaN
#
#    home_shots_inb  away_shots_inb  home_shots_outb  away_shots_outb  \
# 0             NaN             NaN              NaN              NaN
# 1             NaN             NaN              NaN              NaN
# 2             NaN             NaN              NaN              NaN
# 3             NaN             NaN              NaN              NaN
# 4             NaN             NaN              NaN              NaN
#
#    home_passes_acc  away_passes_acc  home_passes_tot  away_passes_tot  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#   home_passes_pct away_passes_pct home_possession away_possession  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    home_corners  away_corners  home_offsides  away_offsides  home_fouls  \
# 0           NaN           NaN            NaN            NaN         NaN
# 1           NaN           NaN            NaN            NaN         NaN
# 2           NaN           NaN            NaN            NaN         NaN
# 3           NaN           NaN            NaN            NaN         NaN
# 4           NaN           NaN            NaN            NaN         NaN
#
#    away_fouls  home_yc  away_yc  home_rc  away_rc  home_gksaves  away_gksaves  \
# 0         NaN      NaN      NaN      NaN      NaN           NaN           NaN
# 1         NaN      NaN      NaN      NaN      NaN           NaN           NaN
# 2         NaN      NaN      NaN      NaN      NaN           NaN           NaN
# 3         NaN      NaN      NaN      NaN      NaN           NaN           NaN
# 4         NaN      NaN      NaN      NaN      NaN           NaN           NaN
#
#    home_shots_bl  away_shots_bl
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN

# %%
print("Unique fixture ID's:", len(match_stats.fixture_id.unique()), "\n")
print("Countries"); print(match_stats.country.value_counts(), "\n")
print("League Name"); print(match_stats.league_name.value_counts(), "\n")
print("League Type"); print(match_stats.league_type.value_counts(), "\n")
print("Season"); print(match_stats.league_season.value_counts(), "\n")
print("Has some match statistics?"); print(match_stats.has_match_stats.value_counts(), "\n")
print("Fixture Status"); print(match_stats.fixture_status.value_counts(), "\n")
# Out:
# Unique fixture ID's: 23677
#
# Countries
# England    5211
# France     4753
# Italy      4097
# Spain      4035
# Germany    3307
# World      2274
# Name: country, dtype: int64
#
# League Name
# Ligue 1              3802
# Serie A              3800
# Primera Division     3800
# Premier League       3790
# Bundesliga 1         3062
# Europa League        1419
# FA Cup               1328
# Champions League      855
# Coupe de France       778
# Coppa Italia          297
# DFB Pokal             245
# Copa del Rey          235
# Coupe de la Ligue     173
# League Cup             93
# Name: league_name, dtype: int64
#
# League Type
# League    18254
# Cup        5423
# Name: league_type, dtype: int64
#
# Season
# 2019    3980
# 2018    3205
# 2017    2779
# 2016    2767
# 2015    1826
# 2013    1826
# 2014    1826
# 2011    1826
# 2012    1826
# 2010    1816
# Name: league_season, dtype: int64
#
# Has some match statistics?
# False    15229
# True      8448
# Name: has_match_stats, dtype: int64
#
# Fixture Status
# Match Finished        22863
# Not Started             633
# Time to be defined      167
# First Half                9
# Match Cancelled           3
# Match Postponed           2
# Name: fixture_status, dtype: int64

# %% [markdown]
# Having looked through the dates of matches with Fixture status other than 'Match Finished', we see 99% are from this season. To begin with I think we will exclude matches from this season from our analysis since it is ongoing. However, we might be able to use it as the test data set when splitting our data.

# %%
match_stats_filtered = match_stats[match_stats.fixture_status == "Match Finished"].copy()
match_stats_filtered = match_stats_filtered[match_stats_filtered.league_season != "2019"].copy()
print(match_stats_filtered.shape)
match_stats_filtered.head()
# Out:
# (19695, 55)
#     fixture_id  country league_name league_id league_type league_season  \
# 873     209926  England      FA Cup       758         Cup          2018
# 874     209927  England      FA Cup       758         Cup          2018
# 875     209928  England      FA Cup       758         Cup          2018
# 876     209929  England      FA Cup       758         Cup          2018
# 877     209930  England      FA Cup       758         Cup          2018
#
#     fixture_date fixture_round  fixture_status fixture_elapsed  \
# 873   09/11/2018     1st Round  Match Finished              90
# 874   10/11/2018     1st Round  Match Finished              90
# 875   10/11/2018     1st Round  Match Finished              90
# 876   10/11/2018     1st Round  Match Finished              90
# 877   10/11/2018     1st Round  Match Finished              90
#
#                              fixture_venue             fixture_referee  \
# 873                    Coles Park (London)  Salisbury Michael, England
# 874                  York Road, Maidenhead    Dean Whitestone, England
# 875           The Crown Ground, Accrington         Martin Coy, England
# 876  Borough Sports Ground, Sutton, London                Sam Purkiss,
# 877                     Plainmoor, Torquay              Declan Bourne,
#
#     fixture_result_ht fixture_result_ft fixture_result_et fixture_result_pen  \
# 873               0-0               0-1               NaN                NaN
# 874               0-1               0-4               NaN                NaN
# 875               1-0               1-0               NaN                NaN
# 876               0-0               0-0               NaN                NaN
# 877               0-0               0-1               NaN                NaN
#
#        home_team_name home_team_id away_team_name away_team_id  home_goals  \
# 873  Haringey Borough         4681  AFC Wimbledon         1333         0.0
# 874        Maidenhead         1838     Portsmouth         1355         0.0
# 875     Accrington ST         1360     Colchester         1361         1.0
# 876        Sutton Utd         1835    Slough Town         4685         0.0
# 877           Torquay         1827         Woking         1836         0.0
#
#      away_goals  has_match_stats  home_shots_ont  away_shots_ont  \
# 873         1.0             True             0.0             5.0
# 874         4.0             True             0.0            12.0
# 875         0.0            False             NaN             NaN
# 876         0.0            False             NaN             NaN
# 877         1.0            False             NaN             NaN
#
#      home_shots_offt  away_shots_offt  home_shots_tot  away_shots_tot  \
# 873              2.0             12.0             4.0            20.0
# 874              5.0              7.0             6.0            25.0
# 875              NaN              NaN             NaN             NaN
# 876              NaN              NaN             NaN             NaN
# 877              NaN              NaN             NaN             NaN
#
#      home_shots_inb  away_shots_inb  home_shots_outb  away_shots_outb  \
# 873             1.0             8.0              3.0             12.0
# 874             3.0            18.0              3.0              7.0
# 875             NaN             NaN              NaN              NaN
# 876             NaN             NaN              NaN              NaN
# 877             NaN             NaN              NaN              NaN
#
#      home_passes_acc  away_passes_acc  home_passes_tot  away_passes_tot  \
# 873            128.0            293.0            265.0            409.0
# 874            114.0            452.0            232.0            564.0
# 875              NaN              NaN              NaN              NaN
# 876              NaN              NaN              NaN              NaN
# 877              NaN              NaN              NaN              NaN
#
#     home_passes_pct away_passes_pct home_possession away_possession  \
# 873             48%             72%             38%             62%
# 874             49%             80%             28%             72%
# 875             NaN             NaN             NaN             NaN
# 876             NaN             NaN             NaN             NaN
# 877             NaN             NaN             NaN             NaN
#
#      home_corners  away_corners  home_offsides  away_offsides  home_fouls  \
# 873           5.0           6.0            1.0            1.0        12.0
# 874           1.0           7.0            NaN            NaN        13.0
# 875           NaN           NaN            NaN            NaN         NaN
# 876           NaN           NaN            NaN            NaN         NaN
# 877           NaN           NaN            NaN            NaN         NaN
#
#      away_fouls  home_yc  away_yc  home_rc  away_rc  home_gksaves  \
# 873        13.0      1.0      0.0      0.0      0.0           4.0
# 874         7.0      NaN      NaN      0.0      0.0           8.0
# 875         NaN      NaN      NaN      NaN      NaN           NaN
# 876         NaN      NaN      NaN      NaN      NaN           NaN
# 877         NaN      NaN      NaN      NaN      NaN           NaN
#
#      away_gksaves  home_shots_bl  away_shots_bl
# 873           0.0            2.0            3.0
# 874           0.0            1.0            6.0
# 875           NaN            NaN            NaN
# 876           NaN            NaN            NaN
# 877           NaN            NaN            NaN

# %%
print("Season"); print(match_stats_filtered.league_season.value_counts(), "\n")
print("Has some match statistics?"); print(match_stats_filtered.has_match_stats.value_counts(), "\n")
print("Fixture Status"); print(match_stats_filtered.fixture_status.value_counts(), "\n")
print("Time Elapsed"); print(match_stats_filtered.fixture_elapsed.value_counts(), "\n")
# Out:
# Season
# 2018    3205
# 2017    2778
# 2016    2766
# 2013    1826
# 2014    1826
# 2011    1826
# 2012    1826
# 2015    1826
# 2010    1816
# Name: league_season, dtype: int64
#
# Has some match statistics?
# False    12998
# True      6697
# Name: has_match_stats, dtype: int64
#
# Fixture Status
# Match Finished    19695
# Name: fixture_status, dtype: int64
#
# Time Elapsed
# 90     19361
# 120      334
# Name: fixture_elapsed, dtype: int64

# %% [markdown]
# We'll now seperate our data between those with and without match statistics

# %%
match_stats_filtered_yes = match_stats_filtered[match_stats_filtered.has_match_stats].copy()
match_stats_filtered_no = match_stats_filtered[~match_stats_filtered.has_match_stats].copy()
print("With match stats:")
print(match_stats_filtered_yes.shape)
display(match_stats_filtered_yes.head(3))
print("\nWithout match stats:")
print(match_stats_filtered_no.shape)
display(match_stats_filtered_no.head(3))
# Out:
# With match stats:
# (6697, 55)
#     fixture_id  country league_name league_id league_type league_season  \
# 873     209926  England      FA Cup       758         Cup          2018
# 874     209927  England      FA Cup       758         Cup          2018
# 880     209933  England      FA Cup       758         Cup          2018
#
#     fixture_date fixture_round  fixture_status fixture_elapsed  \
# 873   09/11/2018     1st Round  Match Finished              90
# 874   10/11/2018     1st Round  Match Finished              90
# 880   10/11/2018     1st Round  Match Finished              90
#
#              fixture_venue             fixture_referee fixture_result_ht  \
# 873    Coles Park (London)  Salisbury Michael, England               0-0
# 874  York Road, Maidenhead    Dean Whitestone, England               0-1
# 880   Imber Court, Molesey       Matt Donohue, England               0-1
#
#     fixture_result_ft fixture_result_et fixture_result_pen  \
# 873               0-1               NaN                NaN
# 874               0-4               NaN                NaN
# 880               0-2               NaN                NaN
#
#           home_team_name home_team_id  away_team_name away_team_id  \
# 873     Haringey Borough         4681   AFC Wimbledon         1333
# 874           Maidenhead         1838      Portsmouth         1355
# 880  Metropolitan Police         4683  Newport County         1367
#
#      home_goals  away_goals  has_match_stats  home_shots_ont  away_shots_ont  \
# 873         0.0         1.0             True             0.0             5.0
# 874         0.0         4.0             True             0.0            12.0
# 880         0.0         2.0             True             6.0             9.0
#
#      home_shots_offt  away_shots_offt  home_shots_tot  away_shots_tot  \
# 873              2.0             12.0             4.0            20.0
# 874              5.0              7.0             6.0            25.0
# 880              2.0              8.0            12.0            21.0
#
#      home_shots_inb  away_shots_inb  home_shots_outb  away_shots_outb  \
# 873             1.0             8.0              3.0             12.0
# 874             3.0            18.0              3.0              7.0
# 880             6.0            11.0              6.0             10.0
#
#      home_passes_acc  away_passes_acc  home_passes_tot  away_passes_tot  \
# 873            128.0            293.0            265.0            409.0
# 874            114.0            452.0            232.0            564.0
# 880            154.0            290.0            262.0            395.0
#
#     home_passes_pct away_passes_pct home_possession away_possession  \
# 873             48%             72%             38%             62%
# 874             49%             80%             28%             72%
# 880             59%             73%             40%             60%
#
#      home_corners  away_corners  home_offsides  away_offsides  home_fouls  \
# 873           5.0           6.0            1.0            1.0        12.0
# 874           1.0           7.0            NaN            NaN        13.0
# 880           9.0           5.0            0.0            4.0        11.0
#
#      away_fouls  home_yc  away_yc  home_rc  away_rc  home_gksaves  \
# 873        13.0      1.0      0.0      0.0      0.0           4.0
# 874         7.0      NaN      NaN      0.0      0.0           8.0
# 880         8.0      3.0      2.0      1.0      0.0           7.0
#
#      away_gksaves  home_shots_bl  away_shots_bl
# 873           0.0            2.0            3.0
# 874           0.0            1.0            6.0
# 880           6.0            4.0            4.0
# Without match stats:
# (12998, 55)
#     fixture_id  country league_name league_id league_type league_season  \
# 875     209928  England      FA Cup       758         Cup          2018
# 876     209929  England      FA Cup       758         Cup          2018
# 877     209930  England      FA Cup       758         Cup          2018
#
#     fixture_date fixture_round  fixture_status fixture_elapsed  \
# 875   10/11/2018     1st Round  Match Finished              90
# 876   10/11/2018     1st Round  Match Finished              90
# 877   10/11/2018     1st Round  Match Finished              90
#
#                              fixture_venue      fixture_referee  \
# 875           The Crown Ground, Accrington  Martin Coy, England
# 876  Borough Sports Ground, Sutton, London         Sam Purkiss,
# 877                     Plainmoor, Torquay       Declan Bourne,
#
#     fixture_result_ht fixture_result_ft fixture_result_et fixture_result_pen  \
# 875               1-0               1-0               NaN                NaN
# 876               0-0               0-0               NaN                NaN
# 877               0-0               0-1               NaN                NaN
#
#     home_team_name home_team_id away_team_name away_team_id  home_goals  \
# 875  Accrington ST         1360     Colchester         1361         1.0
# 876     Sutton Utd         1835    Slough Town         4685         0.0
# 877        Torquay         1827         Woking         1836         0.0
#
#      away_goals  has_match_stats  home_shots_ont  away_shots_ont  \
# 875         0.0            False             NaN             NaN
# 876         0.0            False             NaN             NaN
# 877         1.0            False             NaN             NaN
#
#      home_shots_offt  away_shots_offt  home_shots_tot  away_shots_tot  \
# 875              NaN              NaN             NaN             NaN
# 876              NaN              NaN             NaN             NaN
# 877              NaN              NaN             NaN             NaN
#
#      home_shots_inb  away_shots_inb  home_shots_outb  away_shots_outb  \
# 875             NaN             NaN              NaN              NaN
# 876             NaN             NaN              NaN              NaN
# 877             NaN             NaN              NaN              NaN
#
#      home_passes_acc  away_passes_acc  home_passes_tot  away_passes_tot  \
# 875              NaN              NaN              NaN              NaN
# 876              NaN              NaN              NaN              NaN
# 877              NaN              NaN              NaN              NaN
#
#     home_passes_pct away_passes_pct home_possession away_possession  \
# 875             NaN             NaN             NaN             NaN
# 876             NaN             NaN             NaN             NaN
# 877             NaN             NaN             NaN             NaN
#
#      home_corners  away_corners  home_offsides  away_offsides  home_fouls  \
# 875           NaN           NaN            NaN            NaN         NaN
# 876           NaN           NaN            NaN            NaN         NaN
# 877           NaN           NaN            NaN            NaN         NaN
#
#      away_fouls  home_yc  away_yc  home_rc  away_rc  home_gksaves  \
# 875         NaN      NaN      NaN      NaN      NaN           NaN
# 876         NaN      NaN      NaN      NaN      NaN           NaN
# 877         NaN      NaN      NaN      NaN      NaN           NaN
#
#      away_gksaves  home_shots_bl  away_shots_bl
# 875           NaN            NaN            NaN
# 876           NaN            NaN            NaN
# 877           NaN            NaN            NaN

# %% [markdown]
# We'll have a brief look at the data that don't have match stats so we know what we are currently ignoring

# %%
print("Unique fixture ID's:", len(match_stats_filtered_no.fixture_id.unique()), "\n")
print("Countries"); print(match_stats_filtered_no.country.value_counts(), "\n")
print("League Name"); print(match_stats_filtered_no.league_name.value_counts(), "\n")
print("League Type"); print(match_stats_filtered_no.league_type.value_counts(), "\n")
print("Season"); print(match_stats_filtered_no.league_season.value_counts(), "\n")
print("Fixture Status"); print(match_stats_filtered_no.fixture_status.value_counts(), "\n")
print("Time Elapsed"); print(match_stats_filtered_no.fixture_elapsed.value_counts(), "\n")
# Out:
# Unique fixture ID's: 12998
#
# Countries
# France     2904
# England    2650
# Italy      2456
# Spain      2354
# Germany    1851
# World       783
# Name: country, dtype: int64
#
# League Name
# Primera Division     2319
# Serie A              2292
# Ligue 1              2287
# Premier League       2270
# Bundesliga 1         1836
# Europa League         646
# Coupe de France       520
# FA Cup                380
# Coppa Italia          164
# Champions League      137
# Coupe de la Ligue      97
# Copa del Rey           35
# DFB Pokal              15
# Name: league_name, dtype: int64
#
# League Type
# League    11004
# Cup        1994
# Name: league_type, dtype: int64
#
# Season
# 2013    1826
# 2014    1826
# 2011    1826
# 2012    1826
# 2015    1826
# 2010    1816
# 2017     790
# 2018     636
# 2016     626
# Name: league_season, dtype: int64
#
# Fixture Status
# Match Finished    12998
# Name: fixture_status, dtype: int64
#
# Time Elapsed
# 90     12750
# 120      248
# Name: fixture_elapsed, dtype: int64

# %% [markdown]
# So we can see we don't have match stats for games before the 2016/17 season. We'll recalculate the above just for the seasons we have some match statistics

# %%
match_stats.league_season.unique()
# Out:
# array(['2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012',
#        '2011', '2010'], dtype=object)

# %%
match_stats_filtered_no_aft2016 = match_stats_filtered_no[match_stats_filtered_no.league_season >= '2016']

print("Unique fixture ID's:", len(match_stats_filtered_no_aft2016.fixture_id.unique()), "\n")
print("Countries"); print(match_stats_filtered_no_aft2016.country.value_counts(), "\n")
print("League Name"); print(match_stats_filtered_no_aft2016.league_name.value_counts(), "\n")
print("League Type"); print(match_stats_filtered_no_aft2016.league_type.value_counts(), "\n")
print("Season"); print(match_stats_filtered_no_aft2016.league_season.value_counts(), "\n")
print("Fixture Status"); print(match_stats_filtered_no_aft2016.fixture_status.value_counts(), "\n")
print("Time Elapsed"); print(match_stats_filtered_no_aft2016.fixture_elapsed.value_counts(), "\n")
# Out:
# Unique fixture ID's: 2052
#
# Countries
# World      783
# France     624
# England    380
# Italy      176
# Spain       74
# Germany     15
# Name: country, dtype: int64
#
# League Name
# Europa League        646
# Coupe de France      520
# FA Cup               380
# Coppa Italia         164
# Champions League     137
# Coupe de la Ligue     97
# Primera Division      39
# Copa del Rey          35
# DFB Pokal             15
# Serie A               12
# Ligue 1                7
# Name: league_name, dtype: int64
#
# League Type
# Cup       1994
# League      58
# Name: league_type, dtype: int64
#
# Season
# 2017    790
# 2018    636
# 2016    626
# Name: league_season, dtype: int64
#
# Fixture Status
# Match Finished    2052
# Name: fixture_status, dtype: int64
#
# Time Elapsed
# 90     1804
# 120     248
# Name: fixture_elapsed, dtype: int64

# %% [markdown]
# We'll have a closer look at what rounds from each competition we don't have match_stats for

# %%
for league in match_stats_filtered_no_aft2016.league_name.unique():
    data = match_stats_filtered_no_aft2016[match_stats_filtered_no_aft2016.league_name == league]
    print(league)
    print(data.league_season.unique())
    print(data.fixture_round.value_counts(), "\n")
# Out:
# FA Cup
# ['2018' '2017' '2016']
# 1st Round            112
# 3rd Round             77
# 2nd Round             51
# 4th Round             34
# 1st Round Replays     32
# 3rd Round Replays     19
# 5th Round             16
# 2nd Round Replays     16
# Quarter-finals         8
# 4th Round Replays      6
# Semi-finals            4
# 5th Round Replays      3
# Final                  2
# Name: fixture_round, dtype: int64
#
# Ligue 1
# ['2017' '2016']
# Regular Season - 31                 2
# Regular Season - 33                 2
# Relegation Play Off - Second Leg    1
# Regular Season - 24                 1
# Relegation Play Off - First Leg     1
# Name: fixture_round, dtype: int64
#
# Coupe de la Ligue
# ['2018' '2016' '2017']
# 1st Round         32
# 16th Finals       24
# 8th Finals        19
# 2nd Round         15
# Quarter-finals     4
# Semi-finals        2
# Final              1
# Name: fixture_round, dtype: int64
#
# Coupe de France
# ['2018' '2017' '2016']
# 7th Round      263
# 8th Round      132
# 32nd Finals     80
# 16th Finals     37
# 8th Finals       8
# Name: fixture_round, dtype: int64
#
# Copa del Rey
# ['2018']
# 1st Round    18
# 2nd Round    11
# 3rd Round     6
# Name: fixture_round, dtype: int64
#
# Primera Division
# ['2017']
# Regular Season - 17    7
# Regular Season - 33    4
# Regular Season - 34    3
# Regular Season - 26    3
# Regular Season - 16    2
# Regular Season - 10    2
# Regular Season - 36    1
# Regular Season - 35    1
# Regular Season - 25    1
# Regular Season - 15    1
# Regular Season - 28    1
# Regular Season - 23    1
# Regular Season - 24    1
# Regular Season - 27    1
# Regular Season - 30    1
# Regular Season - 19    1
# Regular Season - 31    1
# Regular Season - 13    1
# Regular Season - 20    1
# Regular Season - 14    1
# Regular Season - 18    1
# Regular Season - 12    1
# Regular Season - 21    1
# Regular Season - 22    1
# Name: fixture_round, dtype: int64
#
# DFB Pokal
# ['2017']
# 3rd Round         8
# Quarter-finals    4
# Semi-finals       2
# Final             1
# Name: fixture_round, dtype: int64
#
# Europa League
# ['2018' '2017' '2016']
# 1st Qualifying Round           89
# 2nd Qualifying Round           64
# 3rd Qualifying Round           47
# Round 32 - Second Leg          32
# Round 32 - First Leg           32
# Play-offs                      22
# Round 16 - Second Leg          16
# Round 16 - First Leg           16
# Preliminary Round              14
# Quarter Finals - Second Leg     8
# Quarter Finals - First Leg      8
# Semi Finals - Second Leg        4
# Semi Finals - First Leg         4
# GROUP E - 4                     2
# GROUP A - 3                     2
# GROUP D - 3                     2
# GROUP G - 5                     2
# GROUP E - 2                     2
# GROUP J - 3                     2
# GROUP K - 4                     2
# GROUP F - Matchday 1            2
# GROUP E - 6                     2
# GROUP F - Matchday 2            2
# GROUP I - 3                     2
# GROUP K - 3                     2
# GROUP B - 5                     2
# GROUP C - Matchday 5            2
# GROUP C - 6                     2
# GROUP I - 1                     2
# GROUP K - Matchday 2            2
# GROUP F - 5                     2
# GROUP B - Matchday 1            2
# GROUP F - 6                     2
# GROUP H - Matchday 1            2
# GROUP F - Matchday 6            2
# GROUP K - 1                     2
# GROUP J - 1                     2
# GROUP F - 2                     2
# GROUP D - 4                     2
# GROUP D - 6                     2
# GROUP K - 6                     2
# GROUP L - Matchday 1            2
# GROUP D - Matchday 3            2
# GROUP A - 4                     2
# GROUP E - Matchday 1            2
# GROUP L - Matchday 2            2
# GROUP C - Matchday 2            2
# GROUP L - 5                     2
# GROUP L - Matchday 6            2
# GROUP C - Matchday 1            2
# GROUP K - Matchday 5            2
# GROUP E - Matchday 3            2
# GROUP E - 1                     2
# GROUP H - Matchday 6            2
# GROUP I - 2                     2
# GROUP G - Matchday 3            2
# GROUP L - 3                     2
# GROUP H - 5                     2
# GROUP C - Matchday 4            2
# GROUP D - 5                     2
# GROUP B - Matchday 5            2
# GROUP I - 5                     2
# GROUP F - 4                     2
# GROUP F - Matchday 4            2
# GROUP G - Matchday 6            2
# GROUP G - Matchday 4            2
# GROUP C - Matchday 3            2
# GROUP C - 5                     2
# GROUP I - Matchday 4            2
# GROUP C - Matchday 6            2
# GROUP J - Matchday 3            2
# GROUP K - Matchday 6            2
# GROUP G - 1                     2
# GROUP I - Matchday 6            2
# GROUP J - Matchday 4            2
# GROUP D - Matchday 1            2
# GROUP I - Matchday 2            2
# GROUP D - Matchday 4            2
# GROUP B - Matchday 4            2
# GROUP K - 2                     2
# GROUP K - Matchday 1            2
# GROUP D - Matchday 6            2
# GROUP F - Matchday 5            2
# GROUP A - Matchday 4            2
# GROUP A - 5                     2
# GROUP E - Matchday 2            2
# GROUP J - Matchday 6            2
# GROUP G - 2                     2
# GROUP G - Matchday 1            2
# GROUP F - 1                     2
# GROUP B - Matchday 6            2
# GROUP E - Matchday 4            2
# GROUP G - 6                     2
# GROUP B - 3                     2
# GROUP I - 6                     2
# GROUP K - Matchday 3            2
# GROUP C - 1                     2
# GROUP D - 1                     2
# GROUP J - 6                     2
# GROUP L - Matchday 3            2
# GROUP H - Matchday 3            2
# GROUP J - 2                     2
# GROUP J - Matchday 2            2
# GROUP H - 1                     2
# GROUP K - 5                     2
# GROUP L - 1                     2
# GROUP L - Matchday 4            2
# GROUP B - 2                     2
# GROUP H - 3                     2
# GROUP L - 2                     2
# GROUP A - Matchday 6            2
# GROUP G - 3                     2
# GROUP B - 6                     2
# GROUP E - 3                     2
# GROUP G - Matchday 5            2
# GROUP J - 5                     2
# GROUP B - 4                     2
# GROUP H - 2                     2
# GROUP D - Matchday 2            2
# GROUP H - 6                     2
# GROUP J - Matchday 5            2
# GROUP H - Matchday 4            2
# GROUP I - Matchday 3            2
# GROUP I - Matchday 1            2
# GROUP E - Matchday 5            2
# GROUP H - Matchday 2            2
# GROUP C - 2                     2
# GROUP E - 5                     2
# GROUP D - Matchday 5            2
# GROUP D - 2                     2
# GROUP A - Matchday 3            2
# GROUP H - 4                     2
# GROUP A - 1                     2
# GROUP J - Matchday 1            2
# GROUP C - 3                     2
# GROUP A - 2                     2
# GROUP L - 4                     2
# GROUP A - Matchday 2            2
# GROUP F - Matchday 3            2
# GROUP I - Matchday 5            2
# GROUP K - Matchday 4            2
# GROUP A - Matchday 5            2
# GROUP H - Matchday 5            2
# GROUP A - Matchday 1            2
# GROUP E - Matchday 6            2
# GROUP I - 4                     2
# GROUP J - 4                     2
# GROUP B - 1                     2
# GROUP G - Matchday 2            2
# GROUP G - 4                     2
# GROUP L - 6                     2
# GROUP L - Matchday 5            2
# GROUP C - 4                     2
# GROUP A - 6                     2
# GROUP B - Matchday 3            2
# GROUP B - Matchday 2            2
# GROUP F - 3                     2
# Final                           1
# FINAL - Final                   1
# Name: fixture_round, dtype: int64
#
# Champions League
# ['2018' '2017' '2016']
# 2nd Qualifying Round         46
# 1st Qualifying Round         38
# 3rd Qualifying Round         23
# 8th Finals                   16
# Quarter-finals                8
# Semi-finals                   4
# Final                         1
# Preliminary Round - Final     1
# Name: fixture_round, dtype: int64
#
# Serie A
# ['2017']
# Regular Season - 27    7
# Regular Season - 3     1
# Regular Season - 12    1
# Regular Season - 28    1
# Regular Season - 24    1
# Regular Season - 26    1
# Name: fixture_round, dtype: int64
#
# Coppa Italia
# ['2018' '2017' '2016']
# 2nd Round         60
# 3rd Round         48
# 1st Round         36
# 8th Finals         8
# Semi-finals        4
# Quarter-finals     4
# 4th Round          3
# Final              1
# Name: fixture_round, dtype: int64

# %% [markdown]
# So we can see that most of the matches without match_statistics are Cup games, which includes the UCL and UEL unfortunately. These are mostly games before the knockout stage. It also includes most of the games that went to extra time. Of the top 5 european leagues, only from Ligue 1 (7), Serie A (12) and Primera Division (39) do some games not have match statistics.
#
# We do see for some of the cups that some important knockout and finals games don't have match statistics but most matches are from early rounds and may possibly be for teams not in the top 5 European leagues. (TODO: We can check this but not now).
#
# So we will ignore these matches for now and focus on the matches with match_statistics

# %% [markdown]
# ---
# <a id='second'></a>

# %% [markdown]
# ## 2) Seperating fixtures into those with all match stats and those with at least some

# %% [markdown]
# We'll start by looking at the breakdown of the data

# %%
print("Unique fixture ID's:", len(match_stats_filtered_yes.fixture_id.unique()), "\n")
print("Countries"); print(match_stats_filtered_yes.country.value_counts(), "\n")
print("League Name"); print(match_stats_filtered_yes.league_name.value_counts(), "\n")
print("League Type"); print(match_stats_filtered_yes.league_type.value_counts(), "\n")
print("Season"); print(match_stats_filtered_yes.league_season.value_counts(), "\n")
print("Fixture Status"); print(match_stats_filtered_yes.fixture_status.value_counts(), "\n")
print("Time Elapsed"); print(match_stats_filtered_yes.fixture_elapsed.value_counts(), "\n")
# Out:
# Unique fixture ID's: 6697
#
# Countries
# France     1229
# England    1215
# Italy      1183
# Spain      1178
# Germany    1094
# World       798
# Name: country, dtype: int64
#
# League Name
# Premier League       1140
# Ligue 1              1135
# Serie A              1128
# Primera Division     1101
# Bundesliga 1          920
# Champions League      515
# Europa League         283
# DFB Pokal             174
# Copa del Rey           77
# FA Cup                 75
# Coupe de France        64
# Coppa Italia           55
# Coupe de la Ligue      30
# Name: league_name, dtype: int64
#
# League Type
# League    5424
# Cup       1273
# Name: league_type, dtype: int64
#
# Season
# 2018    2569
# 2016    2140
# 2017    1988
# Name: league_season, dtype: int64
#
# Fixture Status
# Match Finished    6697
# Name: fixture_status, dtype: int64
#
# Time Elapsed
# 90     6611
# 120      86
# Name: fixture_elapsed, dtype: int64

# %% [markdown]
# Now we will see in detail how much of our data are null values

# %%
match_stats_filtered_yes.isna().sum()
# Out:
# fixture_id               0
# country                  0
# league_name              0
# league_id                0
# league_type              0
# league_season            0
# fixture_date             0
# fixture_round            0
# fixture_status           0
# fixture_elapsed          0
# fixture_venue            0
# fixture_referee       3125
# fixture_result_ht        1
# fixture_result_ft        0
# fixture_result_et     6617
# fixture_result_pen    6656
# home_team_name           0
# home_team_id             0
# away_team_name           0
# away_team_id             0
# home_goals               0
# away_goals               0
# has_match_stats          0
# home_shots_ont           8
# away_shots_ont           8
# home_shots_offt         11
# away_shots_offt         11
# home_shots_tot          10
# away_shots_tot          10
# home_shots_inb         346
# away_shots_inb         346
# home_shots_outb        347
# away_shots_outb        347
# home_passes_acc        346
# away_passes_acc        346
# home_passes_tot        346
# away_passes_tot        346
# home_passes_pct        346
# away_passes_pct        346
# home_possession         25
# away_possession         25
# home_corners             3
# away_corners             3
# home_offsides          218
# away_offsides          217
# home_fouls              11
# away_fouls              11
# home_yc                251
# away_yc                251
# home_rc                556
# away_rc                542
# home_gksaves            35
# away_gksaves            34
# home_shots_bl          371
# away_shots_bl          371
# dtype: int64

# %% [markdown]
# We will filter this data further so that we start only with matches with all match statistics and then check how much is missing from each league and season

# %%
print(match_stats_filtered_yes[data_cfg['MATCH_STAT_COLUMNS']].isna().any(axis=1).value_counts(), "\n")
# Out:
# False    5378
# True     1319
# dtype: int64

# %%
all_match_stats = match_stats_filtered_yes[~match_stats_filtered_yes[data_cfg['MATCH_STAT_COLUMNS']].isna().any(axis=1)]
some_match_stats = match_stats_filtered_yes[match_stats_filtered_yes[data_cfg['MATCH_STAT_COLUMNS']].isna().any(axis=1)]

print(all_match_stats.shape)
display(all_match_stats.head(3))
print(some_match_stats.shape)
display(some_match_stats.head(3))
# Out:
# (5378, 55)
#     fixture_id  country league_name league_id league_type league_season  \
# 873     209926  England      FA Cup       758         Cup          2018
# 880     209933  England      FA Cup       758         Cup          2018
# 903     209956  England      FA Cup       758         Cup          2018
#
#     fixture_date fixture_round  fixture_status fixture_elapsed  \
# 873   09/11/2018     1st Round  Match Finished              90
# 880   10/11/2018     1st Round  Match Finished              90
# 903   11/11/2018     1st Round  Match Finished              90
#
#              fixture_venue             fixture_referee fixture_result_ht  \
# 873    Coles Park (London)  Salisbury Michael, England               0-0
# 880   Imber Court, Molesey       Matt Donohue, England               0-1
# 903  Field Mill, Mansfield       Oliver Yates, England               1-0
#
#     fixture_result_ft fixture_result_et fixture_result_pen  \
# 873               0-1               NaN                NaN
# 880               0-2               NaN                NaN
# 903               1-1               NaN                NaN
#
#           home_team_name home_team_id  away_team_name away_team_id  \
# 873     Haringey Borough         4681   AFC Wimbledon         1333
# 880  Metropolitan Police         4683  Newport County         1367
# 903       Mansfield Town         1374        Charlton         1335
#
#      home_goals  away_goals  has_match_stats  home_shots_ont  away_shots_ont  \
# 873         0.0         1.0             True             0.0             5.0
# 880         0.0         2.0             True             6.0             9.0
# 903         1.0         1.0             True             3.0             4.0
#
#      home_shots_offt  away_shots_offt  home_shots_tot  away_shots_tot  \
# 873              2.0             12.0             4.0            20.0
# 880              2.0              8.0            12.0            21.0
# 903              8.0              8.0            18.0            13.0
#
#      home_shots_inb  away_shots_inb  home_shots_outb  away_shots_outb  \
# 873             1.0             8.0              3.0             12.0
# 880             6.0            11.0              6.0             10.0
# 903            11.0             7.0              7.0              6.0
#
#      home_passes_acc  away_passes_acc  home_passes_tot  away_passes_tot  \
# 873            128.0            293.0            265.0            409.0
# 880            154.0            290.0            262.0            395.0
# 903            257.0            354.0            353.0            455.0
#
#     home_passes_pct away_passes_pct home_possession away_possession  \
# 873             48%             72%             38%             62%
# 880             59%             73%             40%             60%
# 903             73%             78%             45%             55%
#
#      home_corners  away_corners  home_offsides  away_offsides  home_fouls  \
# 873           5.0           6.0            1.0            1.0        12.0
# 880           9.0           5.0            0.0            4.0        11.0
# 903          10.0           5.0            2.0            0.0        11.0
#
#      away_fouls  home_yc  away_yc  home_rc  away_rc  home_gksaves  \
# 873        13.0      1.0      0.0      0.0      0.0           4.0
# 880         8.0      3.0      2.0      1.0      0.0           7.0
# 903        12.0      0.0      4.0      0.0      0.0           3.0
#
#      away_gksaves  home_shots_bl  away_shots_bl
# 873           0.0            2.0            3.0
# 880           6.0            4.0            4.0
# 903           2.0            7.0            1.0
# (1319, 55)
#     fixture_id  country league_name league_id league_type league_season  \
# 874     209927  England      FA Cup       758         Cup          2018
# 958     209863  England      FA Cup       758         Cup          2018
# 964     209869  England      FA Cup       758         Cup          2018
#
#     fixture_date fixture_round  fixture_status fixture_elapsed  \
# 874   10/11/2018     1st Round  Match Finished              90
# 958   05/01/2019     3rd Round  Match Finished              90
# 964   05/01/2019     3rd Round  Match Finished              90
#
#               fixture_venue           fixture_referee fixture_result_ht  \
# 874   York Road, Maidenhead  Dean Whitestone, England               0-1
# 958      Turf Moor, Burnley     Simon Hooper, England               0-0
# 964  Villa Park, Birmingham       Gavin Ward, England               0-1
#
#     fixture_result_ft fixture_result_et fixture_result_pen home_team_name  \
# 874               0-4               NaN                NaN     Maidenhead
# 958               1-0               NaN                NaN        Burnley
# 964               0-3               NaN                NaN    Aston Villa
#
#     home_team_id away_team_name away_team_id  home_goals  away_goals  \
# 874         1838     Portsmouth         1355         0.0         4.0
# 958           44       Barnsley          747         1.0         0.0
# 964           66        Swansea           76         0.0         3.0
#
#      has_match_stats  home_shots_ont  away_shots_ont  home_shots_offt  \
# 874             True             0.0            12.0              5.0
# 958             True             3.0             0.0              5.0
# 964             True             2.0             8.0              7.0
#
#      away_shots_offt  home_shots_tot  away_shots_tot  home_shots_inb  \
# 874              7.0             6.0            25.0             3.0
# 958              6.0             8.0             6.0             NaN
# 964              5.0             9.0            13.0             NaN
#
#      away_shots_inb  home_shots_outb  away_shots_outb  home_passes_acc  \
# 874            18.0              3.0              7.0            114.0
# 958             NaN              NaN              NaN              NaN
# 964             NaN              NaN              NaN              NaN
#
#      away_passes_acc  home_passes_tot  away_passes_tot home_passes_pct  \
# 874            452.0            232.0            564.0             49%
# 958              NaN              NaN              NaN             NaN
# 964              NaN              NaN              NaN             NaN
#
#     away_passes_pct home_possession away_possession  home_corners  \
# 874             80%             28%             72%           1.0
# 958             NaN             47%             53%           4.0
# 964             NaN             46%             54%           9.0
#
#      away_corners  home_offsides  away_offsides  home_fouls  away_fouls  \
# 874           7.0            NaN            NaN        13.0         7.0
# 958           4.0            2.0            4.0         6.0         8.0
# 964           5.0            1.0            0.0         9.0         9.0
#
#      home_yc  away_yc  home_rc  away_rc  home_gksaves  away_gksaves  \
# 874      NaN      NaN      0.0      0.0           8.0           0.0
# 958      NaN      NaN      0.0      0.0           0.0           2.0
# 964      NaN      NaN      0.0      0.0           5.0           2.0
#
#      home_shots_bl  away_shots_bl
# 874            1.0            6.0
# 958            NaN            NaN
# 964            NaN            NaN

# %% [markdown]
# ---
# <a id='third'></a>

# %% [markdown]
# ## 3) Proportions of games that have all match statistics

# %% [markdown]
# The most important games are those from the top 5 leagues, the domestic cup games are not important atm. Those games will be used to supplement how good one team performs against another.
#
# Below we show the proportion of matches with match stats that have all match stats out of all with at least some match stats.

# %%
all_match_stats_count = all_match_stats.groupby(['league_season', 'league_name']).has_match_stats.count()
some_match_stats_count = some_match_stats.groupby(['league_season', 'league_name']).has_match_stats.count()
match_stats_proportion = pd.DataFrame(all_match_stats_count/(all_match_stats_count+some_match_stats_count)).fillna(value=0).round(decimals=2)
display(match_stats_proportion)
# Out:
#                                  has_match_stats
# league_season league_name
# 2016          Bundesliga 1                  0.94
#               Champions League              0.58
#               Coppa Italia                  0.60
#               Coupe de France               0.88
#               Coupe de la Ligue             0.09
#               DFB Pokal                     0.25
#               Ligue 1                       0.92
#               Premier League                0.91
#               Primera Division              0.98
#               Serie A                       0.98
# 2017          Bundesliga 1                  0.90
#               Champions League              0.77
#               Coppa Italia                  0.00
#               Coupe de France               0.00
#               DFB Pokal                     0.98
#               FA Cup                        0.00
#               Ligue 1                       0.92
#               Premier League                0.88
#               Primera Division              0.97
#               Serie A                       0.95
# 2018          Bundesliga 1                  0.65
#               Champions League              0.66
#               Copa del Rey                  0.94
#               Coppa Italia                  0.64
#               Coupe de France               0.00
#               Coupe de la Ligue             0.00
#               DFB Pokal                     0.79
#               Europa League                 0.59
#               FA Cup                        0.80
#               Ligue 1                       0.64
#               Premier League                0.68
#               Primera Division              0.67
#               Serie A                       0.66

# %% [markdown]
# And here is the proportion of matches with all match stats out of all matches in total

# %%
all_matches_count_of_match_stats = match_stats_filtered.groupby(['league_season', 'league_name']).has_match_stats.count()
match_stats_total_proportion = pd.DataFrame(((all_match_stats_count/all_matches_count_of_match_stats).fillna(value=0).round(decimals=2)*100).apply(int))
match_stats_total_proportion
# Out:
#                                  has_match_stats
# league_season league_name
# 2010          Bundesliga 1                     0
#               Ligue 1                          0
#               Premier League                   0
#               Primera Division                 0
#               Serie A                          0
# 2011          Bundesliga 1                     0
#               Ligue 1                          0
#               Premier League                   0
#               Primera Division                 0
#               Serie A                          0
# 2012          Bundesliga 1                     0
#               Ligue 1                          0
#               Premier League                   0
#               Primera Division                 0
#               Serie A                          0
# 2013          Bundesliga 1                     0
#               Ligue 1                          0
#               Premier League                   0
#               Primera Division                 0
#               Serie A                          0
# 2014          Bundesliga 1                     0
#               Ligue 1                          0
#               Premier League                   0
#               Primera Division                 0
#               Serie A                          0
# 2015          Bundesliga 1                     0
#               Ligue 1                          0
#               Premier League                   0
#               Primera Division                 0
#               Serie A                          0
# 2016          Bundesliga 1                    94
#               Champions League                51
#               Coppa Italia                    25
#               Coupe de France                 11
#               Coupe de la Ligue                2
#               DFB Pokal                       25
#               Europa League                    0
#               FA Cup                           0
#               Ligue 1                         92
#               Premier League                  91
#               Primera Division                98
#               Serie A                         98
# 2017          Bundesliga 1                    90
#               Champions League                51
#               Coppa Italia                     0
#               Coupe de France                  0
#               Coupe de la Ligue                0
#               DFB Pokal                       75
#               Europa League                    0
#               FA Cup                           1
#               Ligue 1                         91
#               Premier League                  88
#               Primera Division                87
#               Serie A                         92
# 2018          Bundesliga 1                    65
#               Champions League                55
#               Copa del Rey                    64
#               Coppa Italia                    18
#               Coupe de France                  0
#               Coupe de la Ligue                0
#               DFB Pokal                       79
#               Europa League                   32
#               FA Cup                          39
#               Ligue 1                         64
#               Premier League                  68
#               Primera Division                67
#               Serie A                         66

# %% [markdown]
# ---
# <a id='fourth'></a>

# %% [markdown]
# ## 4) Investigating rows that have at least 1 match stat missing

# %% [markdown]
# To make the most of the data we have, we're going to go back over the matches that have some match stats and break it down

# %%
some_match_stats.head()
# Out:
#     fixture_id  country league_name league_id league_type league_season  \
# 874     209927  England      FA Cup       758         Cup          2018
# 958     209863  England      FA Cup       758         Cup          2018
# 964     209869  England      FA Cup       758         Cup          2018
# 990     209839  England      FA Cup       758         Cup          2018
# 993     209842  England      FA Cup       758         Cup          2018
#
#     fixture_date fixture_round  fixture_status fixture_elapsed  \
# 874   10/11/2018     1st Round  Match Finished              90
# 958   05/01/2019     3rd Round  Match Finished              90
# 964   05/01/2019     3rd Round  Match Finished              90
# 990   26/01/2019     4th Round  Match Finished              90
# 993   26/01/2019     4th Round  Match Finished              90
#
#                    fixture_venue           fixture_referee fixture_result_ht  \
# 874        York Road, Maidenhead  Dean Whitestone, England               0-1
# 958           Turf Moor, Burnley     Simon Hooper, England               0-0
# 964       Villa Park, Birmingham       Gavin Ward, England               0-1
# 990     Liberty Stadium, Swansea   England Darren, England               2-0
# 993  Keepmoat Stadium, Doncaster     Peter Bankes, England               0-0
#
#     fixture_result_ft fixture_result_et fixture_result_pen home_team_name  \
# 874               0-4               NaN                NaN     Maidenhead
# 958               1-0               NaN                NaN        Burnley
# 964               0-3               NaN                NaN    Aston Villa
# 990               4-1               NaN                NaN        Swansea
# 993               2-1               NaN                NaN      Doncaster
#
#     home_team_id away_team_name away_team_id  home_goals  away_goals  \
# 874         1838     Portsmouth         1355         0.0         4.0
# 958           44       Barnsley          747         1.0         0.0
# 964           66        Swansea           76         0.0         3.0
# 990           76     Gillingham         1347         4.0         1.0
# 993         1354         Oldham         1349         2.0         1.0
#
#      has_match_stats  home_shots_ont  away_shots_ont  home_shots_offt  \
# 874             True             0.0            12.0              5.0
# 958             True             3.0             0.0              5.0
# 964             True             2.0             8.0              7.0
# 990             True             7.0             5.0              4.0
# 993             True             5.0             3.0              6.0
#
#      away_shots_offt  home_shots_tot  away_shots_tot  home_shots_inb  \
# 874              7.0             6.0            25.0             3.0
# 958              6.0             8.0             6.0             NaN
# 964              5.0             9.0            13.0             NaN
# 990              3.0            11.0             8.0             NaN
# 993              6.0            11.0             9.0             NaN
#
#      away_shots_inb  home_shots_outb  away_shots_outb  home_passes_acc  \
# 874            18.0              3.0              7.0            114.0
# 958             NaN              NaN              NaN              NaN
# 964             NaN              NaN              NaN              NaN
# 990             NaN              NaN              NaN              NaN
# 993             NaN              NaN              NaN              NaN
#
#      away_passes_acc  home_passes_tot  away_passes_tot home_passes_pct  \
# 874            452.0            232.0            564.0             49%
# 958              NaN              NaN              NaN             NaN
# 964              NaN              NaN              NaN             NaN
# 990              NaN              NaN              NaN             NaN
# 993              NaN              NaN              NaN             NaN
#
#     away_passes_pct home_possession away_possession  home_corners  \
# 874             80%             28%             72%           1.0
# 958             NaN             47%             53%           4.0
# 964             NaN             46%             54%           9.0
# 990             NaN             59%             41%           7.0
# 993             NaN             59%             41%          10.0
#
#      away_corners  home_offsides  away_offsides  home_fouls  away_fouls  \
# 874           7.0            NaN            NaN        13.0         7.0
# 958           4.0            2.0            4.0         6.0         8.0
# 964           5.0            1.0            0.0         9.0         9.0
# 990           6.0            0.0            2.0         6.0        11.0
# 993           1.0            1.0            3.0         9.0        16.0
#
#      home_yc  away_yc  home_rc  away_rc  home_gksaves  away_gksaves  \
# 874      NaN      NaN      0.0      0.0           8.0           0.0
# 958      NaN      NaN      0.0      0.0           0.0           2.0
# 964      NaN      NaN      0.0      0.0           5.0           2.0
# 990      NaN      NaN      0.0      0.0           4.0           3.0
# 993      NaN      NaN      0.0      1.0           2.0           3.0
#
#      home_shots_bl  away_shots_bl
# 874            1.0            6.0
# 958            NaN            NaN
# 964            NaN            NaN
# 990            NaN            NaN
# 993            NaN            NaN

# %%
lots_missing_cols = ["home_shots_inb","away_shots_inb","home_shots_outb","away_shots_outb","home_passes_acc","away_passes_acc","home_passes_tot","away_passes_tot","home_passes_pct","away_passes_pct", "home_shots_bl", "away_shots_bl"]

print(some_match_stats[some_match_stats[lots_missing_cols].isna().all(axis=1)].shape)
print(some_match_stats[~some_match_stats[lots_missing_cols].isna().all(axis=1)].shape)
print(some_match_stats[some_match_stats[lots_missing_cols].isna().any(axis=1)].shape)
# Out:
# (344, 55)
# (975, 55)
# (374, 55)

# %%
some_match_stats[~some_match_stats[lots_missing_cols].isna().all(axis=1)].isna().sum()
# Out:
# fixture_id              0
# country                 0
# league_name             0
# league_id               0
# league_type             0
# league_season           0
# fixture_date            0
# fixture_round           0
# fixture_status          0
# fixture_elapsed         0
# fixture_venue           0
# fixture_referee       169
# fixture_result_ht       0
# fixture_result_ft       0
# fixture_result_et     967
# fixture_result_pen    973
# home_team_name          0
# home_team_id            0
# away_team_name          0
# away_team_id            0
# home_goals              0
# away_goals              0
# has_match_stats         0
# home_shots_ont          0
# away_shots_ont          0
# home_shots_offt         0
# away_shots_offt         0
# home_shots_tot          2
# away_shots_tot          2
# home_shots_inb          2
# away_shots_inb          2
# home_shots_outb         3
# away_shots_outb         3
# home_passes_acc         2
# away_passes_acc         2
# home_passes_tot         2
# away_passes_tot         2
# home_passes_pct         2
# away_passes_pct         2
# home_possession         0
# away_possession         0
# home_corners            0
# away_corners            0
# home_offsides         185
# away_offsides         185
# home_fouls              0
# away_fouls              0
# home_yc               207
# away_yc               207
# home_rc               552
# away_rc               540
# home_gksaves           21
# away_gksaves           21
# home_shots_bl          27
# away_shots_bl          27
# dtype: int64

# %%
cols_to_investigate = data_cfg['MATCH_STAT_COLUMNS']
some_match_stats_investigate = some_match_stats[cols_to_investigate].copy()
missing_col_combinations = []
count = 0

while (len(some_match_stats_investigate)>0) and (count<15):
    count+=1
    count_of_missing_per_row = some_match_stats_investigate[
        some_match_stats_investigate[cols_to_investigate].isna().any(axis=1)].isna().sum(axis=1)
    largest_num_missing_per_row = max(count_of_missing_per_row.unique())
    
    data_subset = some_match_stats_investigate[count_of_missing_per_row == largest_num_missing_per_row]
    subset_columns = sorted(list((data_subset.isna().sum() > 0)[(data_subset.isna().sum() > 0)].index))
                            
    
    missing_col_combinations.append(tuple((subset_columns, len(data_subset))))
    
    some_match_stats_investigate = some_match_stats_investigate[count_of_missing_per_row != largest_num_missing_per_row]

# %%
for columns, num_rows in missing_col_combinations:
    print(num_rows)
    columns = [x.split('away_')[-1] for x in columns[:int(len(columns)/2)]]
    
    print(sorted(columns), "\n")
# Out:
# 2
# ['fouls', 'gksaves', 'offsides', 'passes_acc', 'passes_pct', 'passes_tot', 'possession', 'shots_bl', 'shots_inb', 'shots_offt', 'shots_ont', 'shots_outb', 'shots_tot', 'yc']
#
# 9
# ['corners', 'fouls', 'gksaves', 'offsides', 'passes_acc', 'passes_pct', 'passes_tot', 'possession', 'shots_bl', 'shots_inb', 'shots_offt', 'shots_ont', 'shots_outb', 'shots_tot', 'yc']
#
# 1
# ['gksaves', 'offsides', 'passes_acc', 'passes_pct', 'passes_tot', 'possession', 'shots_bl', 'shots_inb', 'shots_outb', 'yc']
#
# 2
# ['offsides', 'passes_acc', 'passes_pct', 'passes_tot', 'possession', 'shots_bl', 'shots_inb', 'shots_outb', 'yc']
#
# 9
# ['offsides', 'passes_acc', 'passes_pct', 'passes_tot', 'possession', 'rc', 'shots_bl', 'shots_inb', 'shots_outb', 'yc']
#
# 51
# ['gksaves', 'offsides', 'passes_acc', 'passes_pct', 'passes_tot', 'possession', 'rc', 'shots_bl', 'shots_inb', 'shots_outb', 'yc']
#
# 2
# ['passes_acc', 'passes_pct', 'passes_tot', 'shots_bl', 'shots_inb', 'shots_outb']
#
# 270
# ['passes_acc', 'passes_pct', 'passes_tot', 'shots_bl', 'shots_inb', 'shots_outb', 'shots_tot']
#
# 4
# ['gksaves', 'offsides', 'rc', 'yc']
#
# 44
# ['gksaves', 'offsides', 'rc', 'shots_bl', 'yc']
#
# 6
# ['gksaves', 'offsides', 'rc', 'shots_bl', 'yc']
#
# 837
# ['gksaves', 'offsides', 'rc', 'shots_bl', 'shots_outb', 'yc']
#
# 82
# ['rc']

# %% [markdown]
# For now we'll just ignore the partially missing data as we there doesn't seem to be an easy fix right now. TODO: We'll come back and find a way to utilise this data too.

# %% [markdown]
# ---
#  <a id='fifth'></a>

# %% [markdown]
# ## 5) Seperating League and Cup games

# %% [markdown]
# We will start by only looking at those matches that all match statistics
#
# We will look only at league games for now and compare the different leagues

# %%
all_match_stats_league = all_match_stats[all_match_stats.league_type == 'League']
all_match_stats_cup = all_match_stats[all_match_stats.league_type == 'Cup']
print(all_match_stats_league.shape)
print(all_match_stats_cup.shape)
# Out:
# (4572, 55)
# (806, 55)

# %%
print(all_match_stats_league.league_name.value_counts(), "\n")
print(all_match_stats_league.league_season.unique(), "\n")
print(380*3)
print(306*3 + 2)
# Out:
# Serie A             968
# Primera Division    958
# Premier League      941
# Ligue 1             941
# Bundesliga 1        764
# Name: league_name, dtype: int64
#
# ['2018' '2017' '2016']
#
# 1140
# 920

# %% [markdown]
# Note that we expect bundesliga to have a lot less games since they have less fixtures in a season. We see that each league is missing about 150-200 games.

# %%
pd.DataFrame(all_match_stats_league.groupby(['league_name', 'fixture_round']).has_match_stats.count())
# Out:
#                                       has_match_stats
# league_name      fixture_round
# Bundesliga 1     Regular Season - 1                24
#                  Regular Season - 10               24
#                  Regular Season - 11               23
#                  Regular Season - 12               26
#                  Regular Season - 13               27
#                  Regular Season - 14               27
#                  Regular Season - 15               24
#                  Regular Season - 16               23
#                  Regular Season - 17               25
#                  Regular Season - 18               22
#                  Regular Season - 19               24
#                  Regular Season - 2                24
#                  Regular Season - 20               27
#                  Regular Season - 21               27
#                  Regular Season - 22               24
#                  Regular Season - 23               26
#                  Regular Season - 24               24
#                  Regular Season - 25               16
#                  Regular Season - 26               18
#                  Regular Season - 27               18
#                  Regular Season - 28               18
#                  Regular Season - 29               14
#                  Regular Season - 3                25
#                  Regular Season - 30               16
#                  Regular Season - 31               16
#                  Regular Season - 32               15
#                  Regular Season - 33               18
#                  Regular Season - 34               16
#                  Regular Season - 4                27
#                  Regular Season - 5                26
#                  Regular Season - 6                23
#                  Regular Season - 7                27
#                  Regular Season - 8                24
#                  Regular Season - 9                26
# Ligue 1          Regular Season - 1                30
#                  Regular Season - 10               28
#                  Regular Season - 11               27
#                  Regular Season - 12               25
#                  Regular Season - 13               28
#                  Regular Season - 14               27
#                  Regular Season - 15               26
#                  Regular Season - 16               27
#                  Regular Season - 17               27
#                  Regular Season - 18               25
#                  Regular Season - 19               29
#                  Regular Season - 2                29
#                  Regular Season - 20               26
#                  Regular Season - 21               28
#                  Regular Season - 22               28
#                  Regular Season - 23               29
#                  Regular Season - 24               28
#                  Regular Season - 25               28
#                  Regular Season - 26               27
#                  Regular Season - 27               28
#                  Regular Season - 28               20
#                  Regular Season - 29               18
#                  Regular Season - 3                29
#                  Regular Season - 30               18
#                  Regular Season - 31               18
#                  Regular Season - 32               19
#                  Regular Season - 33               14
#                  Regular Season - 34               19
#                  Regular Season - 35               19
#                  Regular Season - 36               19
#                  Regular Season - 37               17
#                  Regular Season - 38               14
#                  Regular Season - 4                28
#                  Regular Season - 5                27
#                  Regular Season - 6                29
#                  Regular Season - 7                27
#                  Regular Season - 8                28
#                  Regular Season - 9                28
# Premier League   Regular Season - 1                29
#                  Regular Season - 10               26
#                  Regular Season - 11               26
#                  Regular Season - 12               27
#                  Regular Season - 13               25
#                  Regular Season - 14               25
#                  Regular Season - 15               26
#                  Regular Season - 16               28
#                  Regular Season - 17               26
#                  Regular Season - 18               27
#                  Regular Season - 19               28
#                  Regular Season - 2                23
#                  Regular Season - 20               28
#                  Regular Season - 21               28
#                  Regular Season - 22               28
#                  Regular Season - 23               29
#                  Regular Season - 24               26
#                  Regular Season - 25               26
#                  Regular Season - 26               29
#                  Regular Season - 27               25
#                  Regular Season - 28               27
#                  Regular Season - 29               29
#                  Regular Season - 3                28
#                  Regular Season - 30               19
#                  Regular Season - 31               20
#                  Regular Season - 32               17
#                  Regular Season - 33               16
#                  Regular Season - 34               20
#                  Regular Season - 35               18
#                  Regular Season - 36               18
#                  Regular Season - 37               17
#                  Regular Season - 38               17
#                  Regular Season - 4                27
#                  Regular Season - 5                23
#                  Regular Season - 6                28
#                  Regular Season - 7                27
#                  Regular Season - 8                28
#                  Regular Season - 9                27
# Primera Division Regular Season - 1                29
#                  Regular Season - 10               27
#                  Regular Season - 11               30
#                  Regular Season - 12               28
#                  Regular Season - 13               28
#                  Regular Season - 14               28
#                  Regular Season - 15               29
#                  Regular Season - 16               28
#                  Regular Season - 17               23
#                  Regular Season - 18               28
#                  Regular Season - 19               29
#                  Regular Season - 2                30
#                  Regular Season - 20               29
#                  Regular Season - 21               28
#                  Regular Season - 22               28
#                  Regular Season - 23               28
#                  Regular Season - 24               28
#                  Regular Season - 25               28
#                  Regular Season - 26               26
#                  Regular Season - 27               18
#                  Regular Season - 28               20
#                  Regular Season - 29               20
#                  Regular Season - 3                29
#                  Regular Season - 30               18
#                  Regular Season - 31               18
#                  Regular Season - 32               20
#                  Regular Season - 33               17
#                  Regular Season - 34               16
#                  Regular Season - 35               19
#                  Regular Season - 36               19
#                  Regular Season - 37               19
#                  Regular Season - 38               18
#                  Regular Season - 4                29
#                  Regular Season - 5                29
#                  Regular Season - 6                30
#                  Regular Season - 7                30
#                  Regular Season - 8                28
#                  Regular Season - 9                29
# Serie A          Regular Season - 1                29
#                  Regular Season - 10               28
#                  Regular Season - 11               28
#                  Regular Season - 12               28
#                  Regular Season - 13               29
#                  Regular Season - 14               29
#                  Regular Season - 15               25
#                  Regular Season - 16               29
#                  Regular Season - 17               30
#                  Regular Season - 18               30
#                  Regular Season - 19               30
#                  Regular Season - 2                29
#                  Regular Season - 20               28
#                  Regular Season - 21               30
#                  Regular Season - 22               30
#                  Regular Season - 23               30
#                  Regular Season - 24               25
#                  Regular Season - 25               27
#                  Regular Season - 26               27
#                  Regular Season - 27               12
#                  Regular Season - 28               20
#                  Regular Season - 29               19
#                  Regular Season - 3                26
#                  Regular Season - 30               20
#                  Regular Season - 31               20
#                  Regular Season - 32               20
#                  Regular Season - 33               20
#                  Regular Season - 34               19
#                  Regular Season - 35               22
#                  Regular Season - 36               20
#                  Regular Season - 37               18
#                  Regular Season - 38               19
#                  Regular Season - 4                29
#                  Regular Season - 5                29
#                  Regular Season - 6                29
#                  Regular Season - 7                28
#                  Regular Season - 8                29
#                  Regular Season - 9                28

# %%
pd.DataFrame(all_match_stats_league.groupby(['fixture_round']).has_match_stats.count()).sort_values(['has_match_stats'], ascending=False)
# Out:
#                      has_match_stats
# fixture_round
# Regular Season - 23              142
# Regular Season - 1               141
# Regular Season - 21              141
# Regular Season - 19              140
# Regular Season - 4               140
# Regular Season - 7               139
# Regular Season - 6               139
# Regular Season - 22              138
# Regular Season - 20              138
# Regular Season - 9               138
# Regular Season - 8               137
# Regular Season - 3               137
# Regular Season - 13              137
# Regular Season - 14              136
# Regular Season - 16              135
# Regular Season - 2               135
# Regular Season - 5               134
# Regular Season - 12              134
# Regular Season - 11              134
# Regular Season - 10              133
# Regular Season - 18              132
# Regular Season - 24              131
# Regular Season - 17              131
# Regular Season - 15              130
# Regular Season - 26              127
# Regular Season - 25              125
# Regular Season - 28              105
# Regular Season - 27              101
# Regular Season - 29              100
# Regular Season - 31               92
# Regular Season - 32               91
# Regular Season - 30               91
# Regular Season - 34               90
# Regular Season - 33               85
# Regular Season - 35               78
# Regular Season - 36               76
# Regular Season - 37               71
# Regular Season - 38               68

# %% [markdown]
# We see that the games later in the season tend to have more matches with missing data

# %%
pd.DataFrame(match_stats_filtered_yes[match_stats_filtered_yes.league_type == 'League'].groupby(['fixture_round']).has_match_stats.count()).sort_values(['has_match_stats'], ascending=False)
# Out:
#                      has_match_stats
# fixture_round
# Regular Season - 9               147
# Regular Season - 8               147
# Regular Season - 6               147
# Regular Season - 32              147
# Regular Season - 29              147
# Regular Season - 7               147
# Regular Season - 1               147
# Regular Season - 4               147
# Regular Season - 2               147
# Regular Season - 5               147
# Regular Season - 11              147
# Regular Season - 18              146
# Regular Season - 25              146
# Regular Season - 30              146
# Regular Season - 3               146
# Regular Season - 19              146
# Regular Season - 14              146
# Regular Season - 13              146
# Regular Season - 23              146
# Regular Season - 15              146
# Regular Season - 21              146
# Regular Season - 20              146
# Regular Season - 22              146
# Regular Season - 28              145
# Regular Season - 12              145
# Regular Season - 16              145
# Regular Season - 10              145
# Regular Season - 24              144
# Regular Season - 31              144
# Regular Season - 34              144
# Regular Season - 26              143
# Regular Season - 33              141
# Regular Season - 17              140
# Regular Season - 27              139
# Regular Season - 37              120
# Regular Season - 38              120
# Regular Season - 36              119
# Regular Season - 35              119
# Finals                             2

# %% [markdown]
# ---
